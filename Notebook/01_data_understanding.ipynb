# %% [markdown]
# # **1. Instalasi Library**

# %%
# !pip install pandas matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LENOVO\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# # **2. Libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **3. Data Loading**

# %% [markdown]
# Memuat dataset dari GitHub

# %%
df_1 = pd.read_csv("https://raw.githubusercontent.com/arawsardni/5---Gaung-Taqwa-Indraswara---Sandra-Triana-Nursyafri/refs/heads/main/Dataset/application_record.csv")
df_2 = pd.read_csv("https://raw.githubusercontent.com/arawsardni/5---Gaung-Taqwa-Indraswara---Sandra-Triana-Nursyafri/refs/heads/main/Dataset/credit_record.csv")

# %% [markdown]
# # **4. Column Description**

# %% [markdown]
# Menerjemahkan Kolom

# %%
column_descriptions = {
    "ID": "ID pelanggan",
    "CODE_GENDER": "Jenis kelamin (M = Male, F = Female)",
    "FLAG_OWN_CAR": "Apakah memiliki mobil (Y = Yes, N = No)",
    "FLAG_OWN_REALTY": "Apakah memiliki properti (Y = Yes, N = No)",
    "CNT_CHILDREN": "Jumlah anak",
    "AMT_INCOME_TOTAL": "Total pendapatan",
    "NAME_INCOME_TYPE": "Jenis pendapatan (Working, Commercial associate, dll.)",
    "NAME_EDUCATION_TYPE": "Tingkat pendidikan",
    "NAME_FAMILY_STATUS": "Status perkawinan",
    "NAME_HOUSING_TYPE": "Jenis tempat tinggal",
    "DAYS_BIRTH": "Usia dalam hari (nilai negatif, karena dihitung dari hari ini)",
    "DAYS_EMPLOYED": "Lama bekerja dalam hari (nilai negatif, karena dihitung dari hari ini)",
    "FLAG_MOBIL": "Apakah memiliki telepon seluler (1 = Yes, 0 = No)",
    "FLAG_WORK_PHONE": "Apakah memiliki telepon kerja (1 = Yes, 0 = No)",
    "FLAG_PHONE": "Apakah memiliki telepon (1 = Yes, 0 = No)",
    "FLAG_EMAIL": "Apakah memiliki email (1 = Yes, 0 = No)",
    "OCCUPATION_TYPE": "Jenis pekerjaan",
    "CNT_FAM_MEMBERS": "Jumlah anggota keluarga",
    "MONTHS_BALANCE": "Bulan sejak pencatatan terakhir",
    "STATUS": "Status pembayaran kredit (C = Closed, X = No Loan, 0 = Current, 1 = 1-29 days overdue, dll.)"
}

# %% [markdown]
# menampilkan deskripsi kolom

# %%
for col, desc in column_descriptions.items():
    print(f"{col}: {desc}")

# %% [markdown]
# # **5. Data Understanding**

# %% [markdown]
# menampilkan 5 baris pertama dari df_1

# %%
df_1
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %% [markdown]
# menampilkan 5 baris pertama dari df_2

# %%
df_2.head()
# Out:
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0      X
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0      C

# %% [markdown]
# informasi tentang struktur data df_1

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   438557 non-null  int64
#  1   CODE_GENDER          438557 non-null  object
#  2   FLAG_OWN_CAR         438557 non-null  object
#  3   FLAG_OWN_REALTY      438557 non-null  object
#  4   CNT_CHILDREN         438557 non-null  int64
#  5   AMT_INCOME_TOTAL     438557 non-null  float64
#  6   NAME_INCOME_TYPE     438557 non-null  object
#  7   NAME_EDUCATION_TYPE  438557 non-null  object
#  8   NAME_FAMILY_STATUS   438557 non-null  object
#  9   NAME_HOUSING_TYPE    438557 non-null  object
#  10  DAYS_BIRTH           438557 non-null  int64
#  11  DAYS_EMPLOYED        438557 non-null  int64
#  12  FLAG_MOBIL           438557 non-null  int64
#  13  FLAG_WORK_PHONE      438557 non-null  int64
#  14  FLAG_PHONE           438557 non-null  int64
# ...

# %% [markdown]
# informasi tentang struktur data df_2

# %%
df_2.info()

# %% [markdown]
# statistik deskriptif untuk df_1

# %%
df_1.describe()

# %% [markdown]
# statistik deskriptif untuk df_2

# %%
df_2.describe()

# %% [markdown]
# # 6. Missing Values

# %%
df_1.isna().sum()
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        134203
# CNT_FAM_MEMBERS             0
# dtype: int64

# %%
df_2.isna().sum()
# Out:
# ID                0
# MONTHS_BALANCE    0
# STATUS            0
# dtype: int64

# %% [markdown]
# # **7. Duplicate Check**

# %%
df_1.duplicated().sum()

# %%
df_2.duplicated().sum()

# %% [markdown]
# # **8. Data Visualization**

# %% [markdown]
# Distribusi pendapatan total (AMT_INCOME_TOTAL)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_1['AMT_INCOME_TOTAL'], bins=30, kde=True)
plt.title('Distribusi Total Pendapatan')
plt.xlabel('Total Pendapatan')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Boxplot untuk pendapatan total

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_1['AMT_INCOME_TOTAL'])
plt.title('Boxplot Total Pendapatan')
plt.xlabel('Total Pendapatan')
plt.show()

# %% [markdown]
# Distribusi status kredit (STATUS)

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='STATUS', data=df_2)
plt.title('Distribusi Status Kredit')
plt.xlabel('Status Kredit')
plt.ylabel('Jumlah')
plt.show()

# %% [markdown]
# # **9. Outlier Check**

# %% [markdown]
# Menghitung IQR untuk AMT_INCOME_TOTAL

# %%
Q1 = df_1['AMT_INCOME_TOTAL'].quantile(0.25)
Q3 = df_1['AMT_INCOME_TOTAL'].quantile(0.75)
IQR = Q3 - Q1

# %% [markdown]
# Menampilkan outlier

# %%
outliers = df_1[(df_1['AMT_INCOME_TOTAL'] < (Q1 - 1.5 * IQR)) | (df_1['AMT_INCOME_TOTAL'] > (Q3 + 1.5 * IQR))]
print("\nOutlier dalam AMT_INCOME_TOTAL:")
print(outliers[['ID', 'AMT_INCOME_TOTAL']])

# %% [markdown]
# # **10. Merge Table**

# %% [markdown]
# Menggabungkan df_1 dan df_2 berdasarkan kolom ID

# %%
df = pd.merge(df_1, df_2, on='ID', how='inner')

df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %% [markdown]
# Menampilkan 5 baris pertama dari dataset yang digabungkan

# %%
df.head()

# %% [markdown]
# Informasi tentang dataset yang digabungkan:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777715 entries, 0 to 777714
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   777715 non-null  int64
#  1   CODE_GENDER          777715 non-null  object
#  2   FLAG_OWN_CAR         777715 non-null  object
#  3   FLAG_OWN_REALTY      777715 non-null  object
#  4   CNT_CHILDREN         777715 non-null  int64
#  5   AMT_INCOME_TOTAL     777715 non-null  float64
#  6   NAME_INCOME_TYPE     777715 non-null  object
#  7   NAME_EDUCATION_TYPE  777715 non-null  object
#  8   NAME_FAMILY_STATUS   777715 non-null  object
#  9   NAME_HOUSING_TYPE    777715 non-null  object
#  10  DAYS_BIRTH           777715 non-null  int64
#  11  DAYS_EMPLOYED        777715 non-null  int64
#  12  FLAG_MOBIL           777715 non-null  int64
#  13  FLAG_WORK_PHONE      777715 non-null  int64
#  14  FLAG_PHONE           777715 non-null  int64
# ...

# %%
dftest = pd.merge(df_1, df_2, on='ID', how='left')

dftest
# Out:
#               ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0        5008804           M            Y               Y             0
# 1        5008804           M            Y               Y             0
# 2        5008804           M            Y               Y             0
# 3        5008804           M            Y               Y             0
# 4        5008804           M            Y               Y             0
# ...          ...         ...          ...             ...           ...
# 1179810  6840104           M            N               Y             0
# 1179811  6840222           F            N               N             0
# 1179812  6841878           F            N               N             0
# 1179813  6842765           F            N               Y             0
# 1179814  6842885           F            N               Y             0
#
#          AMT_INCOME_TOTAL      NAME_INCOME_TYPE  \
# 0                427500.0               Working
# ...

# %%
dftest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1179815 entries, 0 to 1179814
# Data columns (total 20 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   ID                   1179815 non-null  int64
#  1   CODE_GENDER          1179815 non-null  object
#  2   FLAG_OWN_CAR         1179815 non-null  object
#  3   FLAG_OWN_REALTY      1179815 non-null  object
#  4   CNT_CHILDREN         1179815 non-null  int64
#  5   AMT_INCOME_TOTAL     1179815 non-null  float64
#  6   NAME_INCOME_TYPE     1179815 non-null  object
#  7   NAME_EDUCATION_TYPE  1179815 non-null  object
#  8   NAME_FAMILY_STATUS   1179815 non-null  object
#  9   NAME_HOUSING_TYPE    1179815 non-null  object
#  10  DAYS_BIRTH           1179815 non-null  int64
#  11  DAYS_EMPLOYED        1179815 non-null  int64
#  12  FLAG_MOBIL           1179815 non-null  int64
#  13  FLAG_WORK_PHONE      1179815 non-null  int64
# ...

# %% [markdown]
# Statistik deskriptif untuk dataset yang digabungkan:

# %%
df.describe()
